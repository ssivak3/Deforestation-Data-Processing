# %% [markdown]
# # Data Aggregation

# %% [markdown]
# ## Importing Essential Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import rasterio as rio

# %% [markdown]
# ## Loading Agriculture Data

# %%
maize_data_path = "../data/raw/yield_maize.tif"
with rio.open(maize_data_path) as src:
    maize_data = src.read()
maize_data = np.squeeze(maize_data)

# %%
plt.figure(figsize = (20, 8))
plt.title("Maize Data")
plt.imshow(maize_data)
plt.colorbar()
plt.show()

# %%
maize_data.shape
# Out:
# (2160, 4320)

# %%
lat_index = np.arange(0, maize_data.shape[0])
long_index = np.arange(0, maize_data.shape[1])

long_grid, lat_grid = np.meshgrid(long_index, lat_index)
lat_grid_flat = lat_grid.flatten()
long_grid_flat = long_grid.flatten()

# %%
A = src.transform
long, lat = rio.transform.xy(A, lat_grid_flat, long_grid_flat)

# %%
lat = np.array(lat).reshape(maize_data.shape)
long = np.array(long).reshape(maize_data.shape)
print((lat.min(), lat.max()))
print((long.min(), long.max()))
# Out:
# (-89.95833333333333, 89.95833333333333)
# (-179.95833333333334, 179.9583333333333)

# %%
def pix_in_coords(data, lat, long, lat_max, long_max, length):
    lat_min = lat_max - length
    long_min = long_max + length
    print(lat_min, lat_max)
    print(long_min, long_max)
    
    xlen = data.shape[1]
    ylen = data.shape[0]
    # find xmin and xmax
    xmin, xmax = None, None
    for x in range(xlen):
        if long[0, x] > long_min:
            xmin = x if xmin == None else xmin
        if long[0, xlen - x - 1] < long_max:
            xmax = x if xmax == None else xmax
            
    # find ymin and ymax
    ymin, ymax = None, None
    for y in range(ylen):
        if lat[ylen - y - 1, 0] > lat_min:
            ymin = y if ymin == None else ymin
        if lat[y, 0] < lat_max:
            ymax = y if ymax == None else ymax
    print(xmin, xmax)
    print(ymin, ymax)
    return data[xmin:xmax, ymin:ymax]

# %%
# 10S60W
lat_target = -10
long_target = -60
seg = pix_in_coords(maize_data, lat, long, lat_target, long_target, 10)
# Out:
# -20 -10
# -70 -60
# 1320 2880
# 840 1200

# %%
plt.imshow(seg)

# %%
long
# Out:
# array([[-179.95833333, -179.875     , -179.79166667, ...,  179.79166667,
#          179.875     ,  179.95833333],
#        [-179.95833333, -179.875     , -179.79166667, ...,  179.79166667,
#          179.875     ,  179.95833333],
#        [-179.95833333, -179.875     , -179.79166667, ...,  179.79166667,
#          179.875     ,  179.95833333],
#        ...,
#        [-179.95833333, -179.875     , -179.79166667, ...,  179.79166667,
#          179.875     ,  179.95833333],
#        [-179.95833333, -179.875     , -179.79166667, ...,  179.79166667,
#          179.875     ,  179.95833333],
#        [-179.95833333, -179.875     , -179.79166667, ...,  179.79166667,
#          179.875     ,  179.95833333]])

# %%
lat
# Out:
# array([[ 89.95833333,  89.95833333,  89.95833333, ...,  89.95833333,
#          89.95833333,  89.95833333],
#        [ 89.875     ,  89.875     ,  89.875     , ...,  89.875     ,
#          89.875     ,  89.875     ],
#        [ 89.79166667,  89.79166667,  89.79166667, ...,  89.79166667,
#          89.79166667,  89.79166667],
#        ...,
#        [-89.79166667, -89.79166667, -89.79166667, ..., -89.79166667,
#         -89.79166667, -89.79166667],
#        [-89.875     , -89.875     , -89.875     , ..., -89.875     ,
#         -89.875     , -89.875     ],
#        [-89.95833333, -89.95833333, -89.95833333, ..., -89.95833333,
#         -89.95833333, -89.95833333]])

# %%
lat.shape
# Out:
# (2160, 4320)

# %%
maize_data.shape
# Out:
# (2160, 4320)
